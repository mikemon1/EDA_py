# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels as sm
import seaborn as sns
import numpy as np

# %%
# Dataframes and Series

# Determine the number of rows and columns 
df.shape

# See the column names 
df.columns

# %%
# Clean and validate data 

df['column'].value_counts().sort_index()

df['column'].describe()

# %%
# Probability mass functions

import numpy as np
from scipy.stats import norm
import seaborn as sns


sample = np.random.normal(size = 1000)

xs = np.linspace(-3,3)
ys = norm(0,1).pdf(xs)

plt.plot(xs,ys,color = 'gray')

sns.kdeplot(sample)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Exploring Relationships between variables

# Add some random noise to the plot
x_jitter = x + np.random.normal(0,2,size = len(df))
y_jitter = y + np.random.normal(0,2,size = len(df))
plt.plot(x_jitter,y,'o',markersize = 1, alpha = 0.02)
plt.axis([x_min, x_max, y_min, y_max])
plt.show()

sns.violinplot(x, y, data = data, inner = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-861280699927> in <module>
#       2
#       3 # Add some random noise to the plot
# ----> 4 x_jitter = x + np.random.normal(0,2,size = len(df))
#       5 y_jitter = y + np.random.normal(0,2,size = len(df))
#       6 plt.plot(x_jitter,y,'o',markersize = 1, alpha = 0.02)
#
# NameError: name 'x' is not defined

# %%
# Correlation (Pearson correlation coefficient)
xs= np.linspace(-1,1)
ys = xs**2
ys += normal(0,0.05,len(xs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-59ce031ca000> in <module>
#       2 xs= np.linspace(-1,1)
#       3 ys = xs**2
# ----> 4 ys += normal(0,0.05,len(xs))
#
# NameError: name 'normal' is not defined

# %%
# Simple regression
from scipy.stats import linregress

xs= np.linspace(-1,1)
ys = xs*2

res = linregress(xs,ys)
fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx


plt.plot(fx, fy, '-')
plt.show()

# %%
# Multiple regression

import statsmodels.formula.api as smf

# Do not run
results = smf.ols('x ~ y', data = data).fit()
results.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3b139776f66c> in <module>
#       4
#       5 # Do not run
# ----> 6 results = smf.ols('x ~ y', data = data).fit()
#       7 results.params
#       8
#
# NameError: name 'data' is not defined

# %%
df = pd.DataFrame()

df['age'] = np.linspace(18,85)
df['age2'] = df['age']**2

df['educ']=12
df['educ2'] = df['educ']**2



pred12 = results.predict(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-318e2cbe2fdd> in <module>
#       7 df['educ2'] = df['educ']**2
#       8
# ----> 9 pred12 = results.predict(df)
#
# NameError: name 'results' is not defined

# %%
# Logistic Regression

df['column'].value_counts()

df['coulmn'].replace([2],[0], inplace = True)

formula = 'response ~ predictor + C(categorical predictor)'
results = smf.logit(formula, data = data).fit()

result.params
